# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset.shape
# Out:
# (100, 2)

# %%
dataset.head()
# Out:
#           X          y
# 0  0.899058  32.707516
# 1 -0.736311 -37.159065
# 2  0.645475  23.180966
# 3  0.012722   0.284512
# 4 -1.817424 -78.417180

# %%
dataset.describe()
# Out:
#                 X           y
# count  100.000000  100.000000
# mean     0.013946    0.456953
# std      0.941967   36.568258
# min     -2.499103  -90.642957
# 25%     -0.574431  -21.890572
# 50%     -0.008229   -0.723162
# 75%      0.647435   22.611141
# max      2.207857   87.508289

# %%
dataset.plot(x='X', y='y', style='o')
plt.title('X vs Y')
plt.xlabel('X dependency')
plt.ylabel('Score Y')
plt.show()

# %%
X_train = dataset.iloc[:, :-1].values
y_train = dataset.iloc[:, 1].values

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# -0.07926174548865594

# %%
print(regressor.coef_)
# Out:
# [38.44883423]

# %%
dataset = pd.read_csv('test.csv')
X_test = dataset.iloc[:,0].values

# %%
X_test = X_test.reshape(-1,1)
X_test
# Out:
# array([[3.  ],
#        [3.01],
#        [3.02],
#        [3.03],
#        [3.04],
#        [3.05],
#        [3.06],
#        [3.07],
#        [3.08],
#        [3.09],
#        [3.1 ],
#        [3.11],
#        [3.12],
#        [3.13],
#        [3.14],
#        [3.15],
#        [3.16],
#        [3.17],
#        [3.18],
#        [3.19],
#        [3.2 ],
#        [3.21],
#        [3.22],
#        [3.23],
#        [3.24],
#        [3.25],
#        [3.26],
#        [3.27],
#        [3.28],
#        [3.29],
#        [3.3 ],
#        [3.31],
#        [3.32],
#        [3.33],
#        [3.34],
#        [3.35],
#        [3.36],
#        [3.37],
#        [3.38],
#        [3.39],
#        [3.4 ],
#        [3.41],
#        [3.42],
#        [3.43],
#        [3.44],
#        [3.45],
#        [3.46],
#        [3.47],
#        [3.48],
#        [3.49],
#        [3.5 ],
#        [3.51],
#        [3.52],
#        [3.53],
#        [3.54],
#        [3.55],
#        [3.56],
#        [3.57],
# ...

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([115.26724095, 115.65172929, 116.03621764, 116.42070598,
#        116.80519432, 117.18968266, 117.574171  , 117.95865935,
#        118.34314769, 118.72763603, 119.11212437, 119.49661272,
#        119.88110106, 120.2655894 , 120.65007774, 121.03456609,
#        121.41905443, 121.80354277, 122.18803111, 122.57251946,
#        122.9570078 , 123.34149614, 123.72598448, 124.11047282,
#        124.49496117, 124.87944951, 125.26393785, 125.64842619,
#        126.03291454, 126.41740288, 126.80189122, 127.18637956,
#        127.57086791, 127.95535625, 128.33984459, 128.72433293,
#        129.10882127, 129.49330962, 129.87779796, 130.2622863 ,
#        130.64677464, 131.03126299, 131.41575133, 131.80023967,
#        132.18472801, 132.56921636, 132.9537047 , 133.33819304,
#        133.72268138, 134.10716972, 134.49165807, 134.87614641,
#        135.26063475, 135.64512309, 136.02961144, 136.41409978,
#        136.79858812, 137.18307646, 137.56756481, 137.95205315,
# ...

# %%
y_pred = y_pred.reshape(400,1)

# %%
df = pd.DataFrame({'X': X_test.ravel(), 'y': y_pred.ravel()})
df
# Out:
#         X           y
# 0    3.00  115.267241
# 1    3.01  115.651729
# 2    3.02  116.036218
# 3    3.03  116.420706
# 4    3.04  116.805194
# ..    ...         ...
# 395  6.95  267.140136
# 396  6.96  267.524625
# 397  6.97  267.909113
# 398  6.98  268.293601
# 399  6.99  268.678090
#
# [400 rows x 2 columns]

# %%
X_rounded = np.round(df['X'],2)

# %%
df = pd.DataFrame({'X': X_rounded.ravel(), 'y': y_pred.ravel()})
df
# Out:
#         X           y
# 0    3.00  115.267241
# 1    3.01  115.651729
# 2    3.02  116.036218
# 3    3.03  116.420706
# 4    3.04  116.805194
# ..    ...         ...
# 395  6.95  267.140136
# 396  6.96  267.524625
# 397  6.97  267.909113
# 398  6.98  268.293601
# 399  6.99  268.678090
#
# [400 rows x 2 columns]

# %%
df.to_csv('test.csv',index=False)
